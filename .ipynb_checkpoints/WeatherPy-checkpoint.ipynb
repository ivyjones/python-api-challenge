# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 624

# %%
# Save config information:
url='http://api.openweathermap.org/data/2.5/weather?'
units='imperial'
city_data = []

# Build partial query URL:
query_url=f'{url}appid={weather_api_key}&units={units}&q='

city_weather = requests.get(query_url +city)
city_weather_json=city_weather.json()
city_weather_json
# Out:
# {'coord': {'lon': -152.4072, 'lat': 57.79},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 29.71,
#   'feels_like': 17.85,
#   'temp_min': 29.71,
#   'temp_max': 29.71,
#   'pressure': 993,
#   'humidity': 43},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 310},
#  'clouds': {'all': 20},
#  'dt': 1680977730,
#  'sys': {'type': 1,
#   'id': 7668,
#   'country': 'US',
#   'sunrise': 1680967095,
#   'sunset': 1681016657},
#  'timezone': -28800,
#  'id': 5866583,
#  'name': 'Saint Paul Harbor',
#  'cod': 200}

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units='imperial'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    query_url=f'{url}appid={weather_api_key}&units={units}&q='
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_url +city)
        city_weather_json=city_weather.json()
        
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather_json['coord']['lat']
        city_lng = city_weather_json['coord']['lon']
        city_max_temp = city_weather_json['main']['temp_max']
        city_humidity = city_weather_json['main']['humidity']
        city_clouds = city_weather_json['clouds']
        city_wind = city_weather_json['wind']['speed']
        city_country = city_weather_json['sys']['country']
        city_date = city_weather_json['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gotsu
# Processing Record 2 of Set 1 | lata
# Processing Record 3 of Set 1 | paita
# Processing Record 4 of Set 1 | dekar
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | cazaje
# City not found. Skipping...
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | jardim
# Processing Record 9 of Set 1 | bonthe
# Processing Record 10 of Set 1 | bonavista
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | dolores
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | merauke
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | codrington
# Processing Record 19 of Set 1 | kutum
# Processing Record 20 of Set 1 | jubayl
# City not found. Skipping...
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | stari banovci
# Processing Record 24 of Set 1 | sao felix do xingu
# Processing Record 25 of Set 1 | paamiut
# Processing Record 26 of Set 1 | swellendam
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | fare
# Processing Record 32 of Set 1 | asau
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | banda aceh
# Processing Record 36 of Set 1 | balkhash
# Processing Record 37 of Set 1 | vitim
# Processing Record 38 of Set 1 | flinders
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | okha
# Processing Record 29 of Set 4 | kyra
# Processing Record 30 of Set 4 | jalu
# Processing Record 31 of Set 4 | marienburg
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | the valley
# Processing Record 35 of Set 4 | dauphin
# Processing Record 36 of Set 4 | moba
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | merrill
# Processing Record 39 of Set 4 | egvekinot
# Processing Record 40 of Set 4 | aripuana
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | marsa matruh
# Processing Record 44 of Set 4 | san cristobal
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | bintulu
# Processing Record 47 of Set 4 | paracatu
# Processing Record 48 of Set 4 | corinto
# Processing Record 49 of Set 4 | broken hill
# Processing Record 0 of Set 5 | kloulklubed
# Processing Record 1 of Set 5 | cairns
# Processing Record 2 of Set 5 | sinegorye
# Processing Record 3 of Set 5 | abu samrah
# Processing Record 4 of Set 5 | puerto narino
# Processing Record 5 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 5 | shelburne
# Processing Record 7 of Set 5 | te anau
# Processing Record 8 of Set 5 | vestmannaeyjar
# Processing Record 9 of Set 5 | ostrovnoy
# Processing Record 10 of Set 5 | bom jesus
# Processing Record 11 of Set 5 | shimoda
# Processing Record 12 of Set 5 | elizabeth city
# Processing Record 13 of Set 5 | xinye
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | sao jose da coroa grande
# Processing Record 16 of Set 5 | airai
# Processing Record 17 of Set 5 | sao filipe
# Processing Record 18 of Set 5 | gornopravdinsk
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | dipkarpaz
# City not found. Skipping...
# Processing Record 21 of Set 5 | nikolsk
# Processing Record 22 of Set 5 | redcar
# Processing Record 23 of Set 5 | nouakchott
# Processing Record 24 of Set 5 | sri aman
# Processing Record 25 of Set 5 | upernavik
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | labuhan
# Processing Record 28 of Set 5 | shirokiy
# Processing Record 29 of Set 5 | kenai
# Processing Record 30 of Set 5 | bourail
# Processing Record 31 of Set 5 | faanui
# Processing Record 32 of Set 5 | westport
# Processing Record 33 of Set 5 | leningradskiy
# Processing Record 34 of Set 5 | ayan
# Processing Record 35 of Set 5 | lavrentiya
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | vila velha
# Processing Record 38 of Set 5 | worland
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | deputatskiy
# Processing Record 41 of Set 5 | naze
# Processing Record 42 of Set 5 | pestravka
# Processing Record 43 of Set 5 | fort saint james
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | praia
# Processing Record 48 of Set 5 | road town
# Processing Record 49 of Set 5 | miastko
# Processing Record 0 of Set 6 | tornio
# Processing Record 1 of Set 6 | gresham
# Processing Record 2 of Set 6 | lorengau
# Processing Record 3 of Set 6 | aizawl
# Processing Record 4 of Set 6 | omaruru
# Processing Record 5 of Set 6 | alta floresta
# Processing Record 6 of Set 6 | chinhoyi
# Processing Record 7 of Set 6 | ugoofaaru
# Processing Record 8 of Set 6 | sao gabriel da cachoeira
# Processing Record 9 of Set 6 | erenhot
# Processing Record 10 of Set 6 | cockburn town
# Processing Record 11 of Set 6 | wewak
# Processing Record 12 of Set 6 | paz de ariporo
# City not found. Skipping...
# Processing Record 13 of Set 6 | kiri buru
# Processing Record 14 of Set 6 | pangobilian
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | ereymentau
# Processing Record 17 of Set 6 | kilindoni
# Processing Record 18 of Set 6 | hovd
# Processing Record 19 of Set 6 | ulaanbaatar
# Processing Record 20 of Set 6 | am timan
# Processing Record 21 of Set 6 | la ronge
# Processing Record 22 of Set 6 | laureles
# Processing Record 23 of Set 6 | shetpe
# Processing Record 24 of Set 6 | palmer
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | vrangel
# Processing Record 27 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 6 | dongsheng
# Processing Record 29 of Set 6 | olafsvik
# Processing Record 30 of Set 6 | santander
# Processing Record 31 of Set 6 | tamarindo
# Processing Record 32 of Set 6 | santa maria
# Processing Record 33 of Set 6 | reforma
# Processing Record 34 of Set 6 | vila
# Processing Record 35 of Set 6 | karratha
# Processing Record 36 of Set 6 | amazar
# Processing Record 37 of Set 6 | cartagena del chaira
# Processing Record 38 of Set 6 | sandwick
# Processing Record 39 of Set 6 | mormugao
# Processing Record 40 of Set 6 | greenwood
# Processing Record 41 of Set 6 | christchurch
# Processing Record 42 of Set 6 | fort nelson
# Processing Record 43 of Set 6 | biloxi
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | tilichiki
# Processing Record 46 of Set 6 | moussoro
# Processing Record 47 of Set 6 | tocopilla
# Processing Record 48 of Set 6 | ca mau
# Processing Record 49 of Set 6 | laguna
# Processing Record 0 of Set 7 | whitianga
# Processing Record 1 of Set 7 | coihaique
# Processing Record 2 of Set 7 | zaysan
# Processing Record 3 of Set 7 | pozo colorado
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | cam ranh
# Processing Record 6 of Set 7 | nueva loja
# Processing Record 7 of Set 7 | cayenne
# Processing Record 8 of Set 7 | qaqortoq
# Processing Record 9 of Set 7 | sovetskiy
# Processing Record 10 of Set 7 | cartagena
# Processing Record 44 of Set 9 | manitouwadge
# Processing Record 45 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 46 of Set 9 | naters
# Processing Record 47 of Set 9 | los llanos de aridane
# Processing Record 48 of Set 9 | benjamin constant
# Processing Record 49 of Set 9 | porirua
# Processing Record 0 of Set 10 | wattegama
# Processing Record 1 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 10 | vangaindrano
# Processing Record 3 of Set 10 | fallon
# Processing Record 4 of Set 10 | acin
# City not found. Skipping...
# Processing Record 5 of Set 10 | andenes
# Processing Record 6 of Set 10 | osa
# Processing Record 7 of Set 10 | denpasar
# Processing Record 8 of Set 10 | ati
# Processing Record 9 of Set 10 | lufilufi
# Processing Record 10 of Set 10 | sur
# Processing Record 11 of Set 10 | sistranda
# Processing Record 12 of Set 10 | poum
# Processing Record 13 of Set 10 | yumen
# Processing Record 14 of Set 10 | inhambane
# Processing Record 15 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 10 | kijang
# Processing Record 17 of Set 10 | muros
# Processing Record 18 of Set 10 | erdenet
# Processing Record 19 of Set 10 | san patricio
# Processing Record 20 of Set 10 | rio grande
# Processing Record 21 of Set 10 | erzin
# Processing Record 22 of Set 10 | gualaquiza
# Processing Record 23 of Set 10 | seoul
# Processing Record 24 of Set 10 | izumo
# Processing Record 25 of Set 10 | bremerton
# Processing Record 26 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 10 | blagodatnoye
# Processing Record 28 of Set 10 | saginaw
# Processing Record 29 of Set 10 | ordzhonikidzevskaya
# Processing Record 30 of Set 10 | benjamin hill
# Processing Record 31 of Set 10 | turukhansk
# Processing Record 32 of Set 10 | hay river
# Processing Record 33 of Set 10 | iwanai
# Processing Record 34 of Set 10 | franklin
# Processing Record 35 of Set 10 | bay roberts
# Processing Record 36 of Set 10 | pedreiras
# Processing Record 37 of Set 10 | winnemucca
# Processing Record 38 of Set 10 | itaiba
# Processing Record 39 of Set 10 | harper
# Processing Record 40 of Set 10 | gladstone
# Processing Record 41 of Set 10 | teguldet
# Processing Record 42 of Set 10 | phan thiet
# Processing Record 43 of Set 10 | auki
# Processing Record 44 of Set 10 | impfondo
# Processing Record 45 of Set 10 | tagusao
# Processing Record 46 of Set 10 | yenagoa
# Processing Record 47 of Set 10 | evenskjaer
# City not found. Skipping...
# Processing Record 48 of Set 10 | dakoro
# Processing Record 49 of Set 10 | cheremisinovo
# Processing Record 0 of Set 11 | porto velho
# Processing Record 1 of Set 11 | taksimo
# Processing Record 2 of Set 11 | awjilah
# Processing Record 3 of Set 11 | ballina
# Processing Record 4 of Set 11 | linjiang
# Processing Record 5 of Set 11 | tanete
# Processing Record 6 of Set 11 | saint-francois
# Processing Record 7 of Set 11 | norman wells
# Processing Record 8 of Set 11 | tual
# Processing Record 9 of Set 11 | mecca
# Processing Record 10 of Set 11 | starcevo
# Processing Record 11 of Set 11 | constitucion
# Processing Record 12 of Set 11 | smithers
# Processing Record 13 of Set 11 | ambunti
# Processing Record 14 of Set 11 | maues
# Processing Record 15 of Set 11 | calama
# Processing Record 16 of Set 11 | mao
# Processing Record 17 of Set 11 | mago
# Processing Record 18 of Set 11 | tumbes
# Processing Record 19 of Set 11 | chulman
# Processing Record 20 of Set 11 | katsuura
# Processing Record 21 of Set 11 | zhigansk
# Processing Record 22 of Set 11 | tenenkou
# Processing Record 23 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 11 | cortez
# Processing Record 25 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 11 | mandalgovi
# Processing Record 27 of Set 11 | mungeli
# Processing Record 28 of Set 11 | el badari
# City not found. Skipping...
# Processing Record 29 of Set 11 | sharanga
# Processing Record 30 of Set 11 | kirkland lake
# Processing Record 31 of Set 11 | son la
# Processing Record 32 of Set 11 | aykhal
# Processing Record 33 of Set 11 | high prairie
# Processing Record 34 of Set 11 | mount isa
# Processing Record 35 of Set 11 | mareeba
# Processing Record 36 of Set 11 | tianpeng
# Processing Record 37 of Set 11 | clyde river
# Processing Record 38 of Set 11 | broome
# Processing Record 39 of Set 11 | puerto suarez
# Processing Record 40 of Set 11 | darnah
# Processing Record 41 of Set 11 | ambon
# Processing Record 42 of Set 11 | hambantota
# Processing Record 43 of Set 11 | guerrero negro
# Processing Record 44 of Set 11 | koceljeva
# Processing Record 45 of Set 11 | lappersdorf
# Processing Record 46 of Set 11 | rundu
# Processing Record 47 of Set 11 | waipawa
# Processing Record 48 of Set 11 | ercis
# Processing Record 49 of Set 11 | necochea
# Processing Record 0 of Set 12 | rawson
# Processing Record 1 of Set 12 | bilibino
# Processing Record 2 of Set 12 | iracoubo
# Processing Record 3 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 12 | bontang
# Processing Record 5 of Set 12 | kupang
# Processing Record 6 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 8 of Set 12 | adilcevaz
# Processing Record 9 of Set 12 | leshukonskoye
# Processing Record 10 of Set 12 | bacolod
# Processing Record 11 of Set 12 | altstatten
# Processing Record 12 of Set 12 | carauari
# Processing Record 13 of Set 12 | boca do acre
# Processing Record 14 of Set 12 | wanning
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | chokwe
# Processing Record 17 of Set 12 | almaznyy
# Processing Record 18 of Set 12 | serenje
# Processing Record 19 of Set 12 | general roca
# Processing Record 20 of Set 12 | lazo
# Processing Record 21 of Set 12 | taoudenni
# Processing Record 22 of Set 12 | monclova
# Processing Record 23 of Set 12 | erzincan
# Processing Record 24 of Set 12 | yaan
# Processing Record 25 of Set 12 | alofi
# Processing Record 26 of Set 12 | winslow
# Processing Record 27 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 12 | grand-santi
# Processing Record 29 of Set 12 | maraba
# Processing Record 30 of Set 12 | innisfail
# Processing Record 31 of Set 12 | saint-prosper
# Processing Record 32 of Set 12 | prince rupert
# Processing Record 33 of Set 12 | otorohanga
# Processing Record 34 of Set 12 | makung
# City not found. Skipping...
# Processing Record 35 of Set 12 | sehithwa
# Processing Record 36 of Set 12 | aksu
# Processing Record 37 of Set 12 | bukoba
# Processing Record 38 of Set 12 | severo-yeniseyskiy
# Processing Record 39 of Set 12 | la rioja
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | shirdi
# Processing Record 42 of Set 12 | kemin
# Processing Record 43 of Set 12 | berbera
# Processing Record 44 of Set 12 | ordzhonikidze
# Processing Record 45 of Set 12 | nipawin
# Processing Record 46 of Set 12 | birao
# Processing Record 47 of Set 12 | baie-saint-paul
# Processing Record 48 of Set 12 | fez
# Processing Record 49 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 0 of Set 13 | pedernales
# Processing Record 1 of Set 13 | gravdal
# Processing Record 2 of Set 13 | ulaangom
# Processing Record 3 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 13 | shenzhen
# Processing Record 5 of Set 13 | baruun-urt
# Processing Record 6 of Set 13 | kokopo
# Processing Record 7 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 8 of Set 13 | kristinehamn
# Processing Record 9 of Set 13 | fortuna
# Processing Record 10 of Set 13 | hamilton
# Processing Record 11 of Set 13 | mabamba
# Processing Record 12 of Set 13 | port-cartier
# Processing Record 13 of Set 13 | saint-pierre
# Processing Record 14 of Set 13 | burica
# City not found. Skipping...
# Processing Record 15 of Set 13 | creel
# Processing Record 16 of Set 13 | salvacion
# Processing Record 17 of Set 13 | palaikastron
# Processing Record 18 of Set 13 | finschhafen
# Processing Record 19 of Set 13 | koshurnikovo
# Processing Record 20 of Set 13 | samfya
# Processing Record 21 of Set 13 | khor
# Processing Record 22 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 13 | vagur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df=pd.DataFrame(city_data)

# Show Record Count
print(city_data_df.count())
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity   Cloudiness  \
# 0        gotsu  35.0000  132.2167     46.27        66   {'all': 2}
# 1         lata  40.1629   -8.3327     72.91        46  {'all': 76}
# 2        paita  -5.0892  -81.1144     83.53        68  {'all': 44}
# 3        dekar -21.5333   21.9333     77.20        38  {'all': 99}
# 4  port alfred -33.5906   26.8910     64.18        97  {'all': 87}
#
#    Wind Speed Country        Date
# 0        5.12      JP  1680977821
# 1        5.30      PT  1680977821
# 2        6.31      PE  1680977821
# 3        6.17      BW  1680977822
# 4        6.46      ZA  1680977639

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity   Cloudiness  \
# City_ID
# 0              gotsu  35.0000  132.2167     46.27        66   {'all': 2}
# 1               lata  40.1629   -8.3327     72.91        46  {'all': 76}
# 2              paita  -5.0892  -81.1144     83.53        68  {'all': 44}
# 3              dekar -21.5333   21.9333     77.20        38  {'all': 99}
# 4        port alfred -33.5906   26.8910     64.18        97  {'all': 87}
#
#          Wind Speed Country        Date
# City_ID
# 0              5.12      JP  1680977821
# 1              5.30      PT  1680977821
# 2              6.31      PE  1680977821
# 3              6.17      BW  1680977822
# 4              6.46      ZA  1680977639

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values =city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values, edgecolors='black')
plt.title("City Latitude vs Max Temperature")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)
plt.show()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values =city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values, edgecolors='black')
plt.title("City Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
cloudiness=city_data_df['Cloudiness'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
cloudiness
# Out:
# City_ID
# 0        2
# 1       76
# 2       44
# 3       99
# 4       87
#       ...
# 565    100
# 566    100
# 567     63
# 568     35
# 569     75
# Length: 570, dtype: int64

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values =city_data_df['Lat']
y_values =city_data_df['Cloudiness'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
plt.scatter(x_values,y_values, edgecolors='black')
plt.title("City Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)


# Save the figure


# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values =city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values, edgecolors='black')
plt.title("City Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df=city_data_df[city_data_df['Lat'] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity   Cloudiness  \
# City_ID
# 0            gotsu  35.0000  132.2167     46.27        66   {'all': 2}
# 1             lata  40.1629   -8.3327     72.91        46  {'all': 76}
# 7           bonthe   7.5264  -12.5050     84.15        64  {'all': 74}
# 8        bonavista  48.6499  -53.1147     29.03        77  {'all': 93}
# 13          dikson  73.5069   80.5464    -25.13       100  {'all': 25}
#
#          Wind Speed Country        Date
# City_ID
# 0              5.12      JP  1680977821
# 1              5.30      PT  1680977821
# 7             11.77      SL  1680977826
# 8             15.19      CA  1680977820
# 13             2.62      RU  1680977611

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity    Cloudiness  \
# City_ID
# 2              paita  -5.0892  -81.1144     83.53        68   {'all': 44}
# 3              dekar -21.5333   21.9333     77.20        38   {'all': 99}
# 4        port alfred -33.5906   26.8910     64.18        97   {'all': 87}
# 5            mataura -46.1927  168.8643     41.13        95  {'all': 100}
# 6             jardim -21.4803  -56.1381     79.72        69  {'all': 100}
#
#          Wind Speed Country        Date
# City_ID
# 2              6.31      PE  1680977821
# 3              6.17      BW  1680977822
# 4              6.46      ZA  1680977639
# 5              3.20      NZ  1680977826
# 6              4.16      BR  1680977826

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere: City Latitude vs Max Temperature")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Save the figure:
plt.savefig('output_data/Latitude vs. MaxTemp_North.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7457122333812688

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere: City Latitude vs Max Temperature")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq2,(-25,43),fontsize=18, color='darkred')

# Save the figure:
plt.savefig('output_data/Latitude vs. MaxTemp_South.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.5099967773523642

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
#Northern: Humidity vs. Latitude Linear Regression Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere: City Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Save the figure:
plt.savefig('output_data/Latitude vs. Humidity_North.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.08816062657700896

# %%
# Southern Hemisphere: Humidity vs. Latitude Linear Regression Plot

x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere: City Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Save the figure:
plt.savefig('output_data/Latitude vs. Humidity_Soutth.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.05725133215826636

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
#Northern: Humidity vs. Cloudiness Linear Regression Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere: City Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Save the figure:
#plt.savefig('output_data/Latitude vs. MaxTemp_North.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0021090240918278515

# %%
# Southern: Humidity vs. Cloudiness Linear Regression Plot
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere: City Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Save the figure:
plt.savefig('output_data/Latitude vs. MaxTemp_North.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.032092765453669306

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
#Northern: Wind Speed vs. Latitude Linear Regression Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere: City Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Save the figure:
#plt.savefig('output_data/Latitude vs. MaxTemp_North.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.006804673446501783

# %%
# Southern Hemisphere: Wind Speed vs. Latitude Linear Regression Plot
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values:
regress_values = x_values * slope + intercept

#line equation
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

#Create plot
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere: City Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.plot(x_values,regress_values, 'red', linewidth=2)

#Print equation on plot
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(20,5),fontsize=15,color="red")

# Save the figure:
#plt.savefig('output_data/Latitude vs. MaxTemp_North.png')

#Display
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0584271200387114

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
